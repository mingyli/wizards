# %%
from random import *
from itertools import combinations


def minConflicts(constraints, maxIter, numWizards):
    currentState = [[False for x in range(numWizards)] for y in range(numWizards)] #matrix of current booleans
    for r in range(numWizards):
        for c in range(r):
            currentState[r][c]=True #possibly might change this to linearized index
    prevConflicts = 0
    for i in range(maxIter):
        conflicts = numberConflicting(currentState, constraints)
        if conflicts == 0:
            print("SATISFIED", i)
            return currentState, i
        maxResolve = 0
        maxRow = -1
        maxCol = -1
        if conflicts - prevConflicts == 0:
#             print(conflicts)
#             print("kick")
            currentState = kick(currentState)
        else:
            for r in range(numWizards):
                for c in range(r):
                    currentState[r][c]= not currentState[r][c]
                    currentState[c][r]= not currentState[c][r]
                    newConflicts = numberConflicting(currentState, constraints)
                    if conflicts - newConflicts > maxResolve:
                        maxResolve = conflicts - newConflicts
                        maxRow = r
                        maxCol = c
                    currentState[r][c]= not currentState[r][c]
                    currentState[c][r]= not currentState[c][r]
            
            currentState[maxRow][maxCol] = not currentState[maxRow][maxCol]
            currentState[maxCol][maxRow] = not currentState[maxCol][maxRow]
        prevConflicts = conflicts
    print("GIVEN UP after", maxIter, "iterations")
    return currentState, maxIter

def kick(currentState):
    num_wizards = len(currentState)
    for i in range(num_wizards//7):
        r = int(random()*num_wizards)
        c = int(random()*num_wizards)
        currentState[r][c] = not currentState[r][c]
        currentState[c][r] = not currentState[c][r]
    return currentState

def numberConflicting(currentState, constraints):
    conflicts = 0
    for c in constraints:
        if isConflicting(currentState, c):
            conflicts += 1
    return conflicts
        
def isConflicting(currentState, c):
    return not ((currentState[c[2]][c[0]] and currentState[c[2]][c[1]]) 
            or (currentState[c[0]][c[2]] and currentState[c[1]][c[2]]) )

def prettyPrint(a):
    for r in range (len(a)):
            print(a[r])

import matplotlib.pyplot as plt

from random import shuffle, sample
from itertools import combinations

def make_ordering(n):
    """Generates a random ordering of n wizards, returned as a
    shuffled list containing the elements 0, 1, ..., n-1"""
    order = list(range(n))
    shuffle(order)
    return order

def make_constraints(order, num_constraints=500):
    """Randomly generates constraints on the wizards' ordering,
    where a constraint [a b c] means c is not between a and b."""
    combos = []
    
    for i in range(len(order)):
        for j in range(i + 1, len(order)):
            for k in range(0, i):
                combos.append((order[i], order[j], order[k]))
            for k in range(j + 1, len(order)):
                combos.append((order[i], order[j], order[k]))
    return sample(combos, num_constraints)

# %%
n = 10
order = make_ordering(n)
constraints = make_constraints(order, 100)
a, i = minConflicts(constraints, 10000, n)
print(a, i)
# Out:
# SATISFIED 105
# [[False, True, True, False, True, False, False, False, True, False], [False, False, False, False, False, False, False, False, False, False], [False, True, False, False, False, False, False, False, False, False], [True, True, True, False, True, False, True, True, True, True], [False, True, True, False, False, False, False, False, False, False], [True, True, True, True, True, False, True, True, True, True], [True, True, True, False, True, False, False, False, True, True], [True, True, True, False, True, False, True, False, True, True], [False, True, True, False, True, False, False, False, False, False], [True, True, True, False, True, False, False, False, True, False]] 105

# %%
# ************ CHANGE THIS **************** #
n_wizards = 20
#############################################


data = {}

MAX_ITER = 60000

n_samples = 5

c_counts = [20 * c for c in list(range(5,26))] # 100 to 500, intervals of 20

for c_count in c_counts:
    data[c_count] = []
    print("----------------")
    print("constraint count", c_count)
    for i in range(n_samples):
        print()
        print("sample", i)
        order = make_ordering(n_wizards)
        constraints = make_constraints(order, c_count)
        state, iters = minConflicts(constraints, MAX_ITER, n_wizards)
        
        data[c_count].append((order, constraints, state, iters))
# Out:
# ----------------
# constraint count 100
#
# sample 0
# SATISFIED 7113
#
# sample 1
# SATISFIED 10576
#
# sample 2
# GIVEN UP after 60000 iterations
#
# sample 3
# SATISFIED 1653
#
# sample 4
# SATISFIED 1047
# ----------------
# constraint count 120
#
# sample 0
# GIVEN UP after 60000 iterations
#
# sample 1
# SATISFIED 1315
#
# sample 2
# SATISFIED 14512
#
# sample 3
# SATISFIED 12844
#
# sample 4
# SATISFIED 3123
# ----------------
# constraint count 140
#
# sample 0
# SATISFIED 46375
#
# sample 1
# SATISFIED 1188
#
# sample 2
# SATISFIED 34331
#
# sample 3
# GIVEN UP after 60000 iterations
#
# sample 4
# GIVEN UP after 60000 iterations
# ----------------
# constraint count 160
#
# sample 0
# SATISFIED 48795
#
# sample 1
# GIVEN UP after 60000 iterations
#
# sample 2
# SATISFIED 16270
#
# sample 3
# GIVEN UP after 60000 iterations
#
# sample 4
# GIVEN UP after 60000 iterations
# ----------------
# constraint count 180
#
# sample 0
# GIVEN UP after 60000 iterations
#
# sample 1
# SATISFIED 5160
#
# sample 2
# SATISFIED 49368
#
# sample 3
# SATISFIED 39882
#
# sample 4
# GIVEN UP after 60000 iterations
# ----------------
# constraint count 200
#
# sample 0
# GIVEN UP after 60000 iterations
#
# sample 1
# GIVEN UP after 60000 iterations
#
# sample 2
# SATISFIED 46451
#
# sample 3
# GIVEN UP after 60000 iterations
#
# sample 4
# SATISFIED 53337
# ----------------
# constraint count 220
#
# sample 0
# SATISFIED 24866
#
# sample 1
# SATISFIED 24448
#
# sample 2
# SATISFIED 10979
#
# sample 3
# GIVEN UP after 60000 iterations
#
# sample 4
# SATISFIED 27663
# ----------------
# constraint count 240
#
# sample 0
# SATISFIED 27931
#
# sample 1
# GIVEN UP after 60000 iterations
#
# sample 2
# SATISFIED 5717
#
# sample 3
# SATISFIED 3861
#
# sample 4
# SATISFIED 664
# ----------------
# constraint count 260
#
# sample 0
# SATISFIED 2013
#
# sample 1
# SATISFIED 2375
#
# sample 2
# SATISFIED 1346
#
# sample 3
# SATISFIED 1471
#
# sample 4
# SATISFIED 684
# ----------------
# constraint count 280
#
# sample 0
# SATISFIED 5220
#
# sample 1
# SATISFIED 23739
#
# sample 2
# SATISFIED 3137
#
# sample 3
# SATISFIED 7298
#
# sample 4
# SATISFIED 16028
# ----------------
# constraint count 300
#
# sample 0
# SATISFIED 15291
#
# sample 1
# SATISFIED 2422
#
# sample 2
# SATISFIED 7991
#
# sample 3
# SATISFIED 2620
#
# sample 4
# SATISFIED 9755
# ----------------
# constraint count 320
#
# sample 0
# SATISFIED 1994
#
# sample 1
# SATISFIED 1914
#
# sample 2
# SATISFIED 2392
#
# sample 3
# SATISFIED 4291
#
# sample 4
# SATISFIED 10012
# ----------------
# constraint count 340
#
# sample 0
# SATISFIED 1408
#
# sample 1
# SATISFIED 1124
#
# sample 2
# SATISFIED 4682
#
# sample 3
# SATISFIED 1517
#
# sample 4
# SATISFIED 11564
# ----------------
# constraint count 360
#
# sample 0
# SATISFIED 2248
#
# sample 1
# SATISFIED 2152
#
# sample 2
# SATISFIED 2154
#
# sample 3
# SATISFIED 1340
#
# sample 4
# GIVEN UP after 60000 iterations
# ----------------
# constraint count 380
#
# sample 0
# SATISFIED 1990
#
# sample 1
# SATISFIED 9319
#
# sample 2
# SATISFIED 439
#
# sample 3
# SATISFIED 1003
#
# sample 4
# SATISFIED 429
# ----------------
# constraint count 400
#
# sample 0
# SATISFIED 1087
#
# sample 1
# SATISFIED 934
#
# sample 2
# SATISFIED 977
#
# sample 3
# SATISFIED 1958
#
# sample 4
# SATISFIED 61
# ----------------
# constraint count 420
#
# sample 0
# SATISFIED 1010
#
# sample 1
# SATISFIED 749
#
# sample 2
# SATISFIED 1962
#
# sample 3
# SATISFIED 1579
#
# sample 4
# SATISFIED 801
# ----------------
# constraint count 440
#
# sample 0
# SATISFIED 530
#
# sample 1
# SATISFIED 208
#
# sample 2
# SATISFIED 2455
#
# sample 3
# SATISFIED 1157
#
# sample 4
# SATISFIED 856
# ----------------
# constraint count 460
#
# sample 0
# SATISFIED 291
#
# sample 1
# SATISFIED 2845
#
# sample 2
# SATISFIED 627
#
# sample 3
# SATISFIED 738
#
# sample 4
# SATISFIED 41594
# ----------------
# constraint count 480
#
# sample 0
# SATISFIED 2660
#
# sample 1
# SATISFIED 991
#
# sample 2
# SATISFIED 85
#
# sample 3
# SATISFIED 130
#
# sample 4
# SATISFIED 365
# ----------------
# constraint count 500
#
# sample 0
# SATISFIED 407
#
# sample 1
# SATISFIED 425
#
# sample 2
# SATISFIED 106
#
# sample 3
# SATISFIED 423
#
# sample 4
# SATISFIED 136

# %%
# PLOTTING
xs, ys = [], []

for k, v in data.items():
    for result in v:
        xs.append(k)
        ys.append(result[3])
plt.title("Iterations required to solve")
plt.xlabel("Num of Constraints")
plt.ylabel("Iterations")
plt.scatter(xs, ys)
plt.show()

for k, v in data.items():
    print()
    print(k, "constraints")
    iters_all = [result[3] for result in v]
    print("mean", sum(iters_all)/len(iters_all), "med", iters_all[len(iters_all)//2], "max", max(iters_all))
# Out:
# 160 constraints
# mean 49013.0 med 16270 max 60000
#
# 320 constraints
# mean 4120.6 med 2392 max 10012
#
# 500 constraints
# mean 299.4 med 106 max 425
#
# 440 constraints
# mean 1041.2 med 2455 max 2455
#
# 100 constraints
# mean 16077.8 med 60000 max 60000
#
# 360 constraints
# mean 13578.8 med 2154 max 60000
#
# 200 constraints
# mean 55957.6 med 46451 max 60000
#
# 140 constraints
# mean 40378.8 med 34331 max 60000
#
# 420 constraints
# mean 1220.2 med 1962 max 1962
#
# 300 constraints
# mean 7615.8 med 7991 max 15291
#
# 460 constraints
# mean 9219.0 med 627 max 41594
#
# 340 constraints
# mean 4059.0 med 4682 max 11564
#
# 240 constraints
# mean 19634.6 med 5717 max 60000
#
# 280 constraints
# mean 11084.4 med 3137 max 23739
#
# 400 constraints
# mean 1003.4 med 977 max 1958
#
# 180 constraints
# mean 42882.0 med 49368 max 60000
#
# 480 constraints
# mean 846.2 med 85 max 2660
#
# 120 constraints
# mean 18358.8 med 14512 max 60000
#
# 260 constraints
# mean 1577.8 med 1346 max 2375
#
# 220 constraints
# mean 29591.2 med 10979 max 60000
#
# 380 constraints
# mean 2636.0 med 439 max 9319

# %%
import json

with open('data-Andrew-20.txt', 'w') as outfile:
    json.dump(data, outfile)
